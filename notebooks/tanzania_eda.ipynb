# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
df = pd.read_csv("../data/tanzania.csv")
df.head()
# Out:
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0  2015    1  27.56    29.52    26.22       3.30         7.24  80.97  4.68
# 1  2015    2  27.59    29.99    25.92       4.07         3.40  79.63  4.48
# 2  2015    3  27.47    29.29    26.25       3.04         7.17  80.02  4.91
# 3  2015    4  27.28    29.17    25.96       3.21        16.07  81.78  4.88
# 4  2015    5  26.68    27.83    25.84       1.99        18.83  82.99  4.17
#
#    WS2M_MAX      PS   QV2M
# 0      6.01  100.52  18.61
# 1      5.28  100.52  18.31
# 2      5.99  100.56  18.30
# 3      6.07  100.47  18.52
# 4      5.98  100.43  18.16

# %%
df["Date"] = pd.to_datetime(df["YEAR"] * 1000 + df["DOY"], format="%Y%j")
df["Month"] = df["Date"].dt.month

# %% [markdown]
# ## Data Cleaning
# - Replace -999 with NaN
# - Remove duplicates
# - Handle missing values

# %%
df.replace(-999, np.nan, inplace=True)
df.drop_duplicates(inplace=True)
df.ffill(inplace=True)
# Out:
#       YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0     2015    1  27.56    29.52    26.22       3.30         7.24  80.97  4.68
# 1     2015    2  27.59    29.99    25.92       4.07         3.40  79.63  4.48
# 2     2015    3  27.47    29.29    26.25       3.04         7.17  80.02  4.91
# 3     2015    4  27.28    29.17    25.96       3.21        16.07  81.78  4.88
# 4     2015    5  26.68    27.83    25.84       1.99        18.83  82.99  4.17
# ...    ...  ...    ...      ...      ...        ...          ...    ...   ...
# 4103  2026   86  27.63    30.65    25.66       4.99         2.96  77.48  1.57
# 4104  2026   87  27.51    31.23    24.84       6.39         1.65  77.72  1.36
# 4105  2026   88  27.74    31.21    25.33       5.88         1.28  77.35  1.53
# 4106  2026   89  27.83    31.29    25.31       5.98         0.92  76.50  1.64
# 4107  2026   90  28.14    31.55    26.06       5.49         0.83  74.46  1.35
#
# ...

# %%
(df.isna().sum() / len(df)) * 100
# Out:
# YEAR           0.0
# DOY            0.0
# T2M            0.0
# T2M_MAX        0.0
# T2M_MIN        0.0
# T2M_RANGE      0.0
# PRECTOTCORR    0.0
# RH2M           0.0
# WS2M           0.0
# WS2M_MAX       0.0
# PS             0.0
# QV2M           0.0
# Date           0.0
# Month          0.0
# dtype: float64

# %%
df.describe()
# Out:
#               YEAR          DOY          T2M      T2M_MAX     T2M_MIN  \
# count  4108.000000  4108.000000  4108.000000  4108.000000  4108.00000
# mean   2020.131451   180.121227    26.802422    29.163493    25.03813
# min    2015.000000     1.000000    22.680000    25.410000    20.03000
# 25%    2017.000000    86.000000    25.670000    28.090000    23.71000
# 50%    2020.000000   179.000000    26.990000    29.080000    25.37500
# 75%    2023.000000   272.000000    27.900000    30.170000    26.31000
# max    2026.000000   366.000000    29.970000    33.930000    28.01000
# std       3.248907   106.294767     1.325388     1.371155     1.53544
#
#          T2M_RANGE  PRECTOTCORR         RH2M         WS2M     WS2M_MAX  \
# count  4108.000000  4108.000000  4108.000000  4108.000000  4108.000000
# mean      4.125363     3.740256    77.128038     4.105370     5.189248
# min       0.940000     0.000000    60.060000     1.120000     1.550000
# ...

# %%
cols = ["T2M", "T2M_MAX", "T2M_MIN", "PRECTOTCORR", "RH2M", "WS2M", "WS2M_MAX"]

z_scores = (df[cols] - df[cols].mean()) / df[cols].std()
z_scores = z_scores.abs()

outliers = (z_scores > 3)

outlier_counts = outliers.sum()
print(outlier_counts)

total_outliers = outliers.any(axis=1).sum()
print("Total rows with outliers:", total_outliers)
# Out:
# T2M             1
# T2M_MAX         2
# T2M_MIN         4
# PRECTOTCORR    81
# RH2M            2
# WS2M            8
# WS2M_MAX        4
# dtype: int64
# Total rows with outliers: 97

# %% [markdown]
# ### Outlier Detection
#
# Outliers were identified using the Z-score method with a threshold of |Z| > 3.
#
# The results show that PRECTOTCORR (precipitation) has the highest number of outliers (81),  Other variables such as temperature (T2M), wind speed (WS2M, WS2M_MAX), and maximum temperature (T2M_MAX) show few or no extreme values.
#
# In total, 97 rows contain at least one outlier across the selected variables.
#
# These outliers are likely to represent real extreme weather events (such as heavy rainfall or unusually low temperatures) rather than data errors. Therefore, they were retained in the dataset to preserve important climate variability and extreme event information.

# %% [markdown]
# ## Temperature Analysis

# %%
monthly_temp = df.groupby("Month")["T2M"].mean()

monthly_temp.plot(figsize=(10,5), title="Monthly Avg Temperature")
plt.show()

# %% [markdown]
# ## Rainfall Trend

# %%
monthly_rain = df.groupby("Month")["PRECTOTCORR"].sum()

monthly_rain.plot(kind="bar", figsize=(10,5), title="Monthly Rainfall")
plt.show()

# %% [markdown]
# ## Corelation Analysis

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.show()

# %% [markdown]
# ## Distribution Analysis|

# %%
df["PRECTOTCORR"].hist(bins=30)
plt.title("Rainfall Distribution")
plt.show()

# %%
plt.scatter(df["T2M"], df["RH2M"], s=df["PRECTOTCORR"]*5, alpha=0.5)
plt.xlabel("Temperature")
plt.ylabel("Humidity")
plt.title("Temp vs Humidity (Bubble = Rainfall)")
plt.show()

# %%
df.to_csv("../data/tanzania_clean.csv", index=False)
